# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_pickle('dados/df_filtrado.pkl')

# %%
df.head()
# Out:
#    EmployeeNumber  Age Attrition              Department  Education  \
# 0               1   41       Yes                   Sales          2
# 1               2   49        No  Research & Development          1
# 2               4   37       Yes  Research & Development          2
# 3               5   33        No  Research & Development          4
# 4               7   27        No  Research & Development          1
#
#   EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0  Life Sciences                        2  Female               3         2
# 1  Life Sciences                        3    Male               2         2
# 2          Other                        4    Male               2         1
# 3  Life Sciences                        4  Female               3         1
# 4        Medical                        1    Male               3         1
#
#                  JobRole  JobSatisfaction  MonthlyIncome  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Attrition                 1470 non-null   object
#  3   Department                1470 non-null   object
#  4   Education                 1470 non-null   int64
#  5   EducationField            1470 non-null   object
#  6   EnvironmentSatisfaction   1470 non-null   int64
#  7   Gender                    1470 non-null   object
#  8   JobInvolvement            1470 non-null   int64
#  9   JobLevel                  1470 non-null   int64
#  10  JobRole                   1470 non-null   object
#  11  JobSatisfaction           1470 non-null   int64
#  12  MonthlyIncome             1470 non-null   int64
#  13  RelationshipSatisfaction  1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#        EmployeeNumber          Age    Education  EnvironmentSatisfaction  \
# count     1470.000000  1470.000000  1470.000000              1470.000000
# mean      1024.865306    36.923810     2.912925                 2.721769
# std        602.024335     9.135373     1.024165                 1.093082
# min          1.000000    18.000000     1.000000                 1.000000
# 25%        491.250000    30.000000     2.000000                 2.000000
# 50%       1020.500000    36.000000     3.000000                 3.000000
# 75%       1555.750000    43.000000     4.000000                 4.000000
# max       2068.000000    60.000000     5.000000                 4.000000
#
#        JobInvolvement     JobLevel  JobSatisfaction  MonthlyIncome  \
# count     1470.000000  1470.000000      1470.000000    1470.000000
# mean         2.729932     2.063946         2.728571    6502.931293
# std          0.711561     1.106940         1.102846    4707.956783
# ...

# %% [markdown]
# Informações retiradas da célula acima:
#
# A idade mínima dos funcionários é 18;
#
# A idade máxima é 60 anos;
#
# A média das idades é 37 anos;
#
# Satisfação no trabalho, relações e ambiente: 2.7 para ambos;
#
# Média salarial: 6500;
#
# Média de anos na empresa: 7 anos.

# %%
df['Attrition'].describe()
# Out:
# count     1470
# unique       2
# top         No
# freq      1233
# Name: Attrition, dtype: object

# %% [markdown]
# A maior parte dos funcionários apresentaram "Attrition" igual a "no": 1233 de 1470.
#
# Isso significa, de um modo geral, que a rotatividade não é alta.
